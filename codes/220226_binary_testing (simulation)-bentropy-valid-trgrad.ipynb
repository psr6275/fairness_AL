# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
device = torch.device('cuda:2')

# %%
from utils.test_utils import obtain_AL_ckpts, split_AL_loaders
from utils.test_utils import load_AL_config, load_AL_dataloader, load_test_model

# %%
save_dir = '../results/simulation/220226_1415'
config_file, state_list, data_files = obtain_AL_ckpts(save_dir)
# Out:
# unknown file:  train_AL_valid_trgrad.txt

# %%
print(state_list, data_files)
# Out:
# ['binaryNN_0.pt', 'binaryNN_1.pt', 'binaryNN_2.pt', 'binaryNN_3.pt', 'binaryNN_4.pt', 'binaryNN_5.pt', 'binaryNN_6.pt', 'binaryNN_7.pt', 'binaryNN_8.pt', 'binaryNN_9.pt'] ['test_loader.pkl', 'final_dataloader.pkl']

# %% [markdown]
# ### load models and train data loaders

# %%
args = load_AL_config(save_dir, config_file)
dl_loader = load_AL_dataloader(args.save_dir,'final_dataloader.pkl')
test_loader = load_AL_dataloader(args.save_dir,'test_loader.pkl')

# %%
dl_loaders,dl_cum_loaders = split_AL_loaders(dl_loader, args)
# Out:
# /home/saerom/fairness/fairness_AL/codes/utils/data_utils.py:141: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   tensors = (torch.tensor(da).clone().detach().float() for da in dataarrays)

# %%
from utils.test_utils import test_groupwise, test_model

# %%
for it,st in enumerate(state_list):
    print("="*50)
    clf,clf_criterion = load_test_model(save_dir, st, args)
    _, acc = test_model(clf, dl_cum_loaders[it],clf_criterion, device, args.problem_type)
    _, acc2 = test_model(clf, test_loader,clf_criterion, device, args.problem_type)
    print("cumulated total training/test acc:", acc,"/",acc2)
    test_groupwise(clf, dl_cum_loaders[it],clf_criterion, device, 
               AL_select = args.AL_select, problem_type = args.problem_type, return_loader=False)
    print("test set performance")
    test_groupwise(clf, test_loader,clf_criterion, device, 
               AL_select = args.AL_select, problem_type = args.problem_type, return_loader=False)
    print('-'*50)
    for i in range(it+1):
        _, acc = test_model(clf, dl_loaders[i],clf_criterion, device, args.problem_type)
        print("data loader",i, "acc:",acc)
        test_groupwise(clf, dl_loaders[i],clf_criterion, device, 
               AL_select = args.AL_select, problem_type = args.problem_type, return_loader=False)
        print("")
# Out:
# ==================================================
# loaded model is binaryNN_0.pt
# /home/saerom/fairness/fairness_AL/codes/utils/eval_utils.py:39: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   pred = torch.tensor(output>thr,dtype = torch.float32)
# cumulated total training/test acc: tensor(82.) / tensor(59.3824)
# 0.0 : loss 0.3769323527812958 / acc 87.14286041259766
# 1.0 : loss 0.5357421040534973 / acc 70.0
# test set performance
# 0.0 : loss 0.7634161710739136 / acc 57.3289909362793
# 1.0 : loss 0.688520073890686 / acc 64.91227722167969
# --------------------------------------------------
# data loader 0 acc: tensor(82.)
# 0.0 : loss 0.3769323527812958 / acc 87.14286041259766
# 1.0 : loss 0.5357421040534973 / acc 70.0
#
# ==================================================
# loaded model is binaryNN_1.pt
# cumulated total training/test acc: tensor(93.1818) / tensor(61.7577)
# 0.0 : loss 0.271202951669693 / acc 92.13483428955078
# 1.0 : loss 0.2266680896282196 / acc 95.34883880615234
# test set performance
# 0.0 : loss 0.9750301241874695 / acc 63.84364700317383
# 1.0 : loss 1.0459903478622437 / acc 56.140350341796875
# --------------------------------------------------
# data loader 0 acc: tensor(91.)
# 0.0 : loss 0.32859957218170166 / acc 90.0
# 1.0 : loss 0.2996242046356201 / acc 93.33332824707031
#
# data loader 1 acc: tensor(100.)
# 0.0 : loss 0.05958619341254234 / acc 100.0
# 1.0 : loss 0.05830690264701843 / acc 100.0
#
# ==================================================
# loaded model is binaryNN_2.pt
# cumulated total training/test acc: tensor(89.6341) / tensor(61.9953)
# 0.0 : loss 0.3476748466491699 / acc 88.59648895263672
# 1.0 : loss 0.2479662299156189 / acc 92.0
# test set performance
# 0.0 : loss 0.8402124047279358 / acc 62.21498489379883
# 1.0 : loss 0.813352108001709 / acc 61.403507232666016
# --------------------------------------------------
# data loader 0 acc: tensor(87.)
# 0.0 : loss 0.4221208393573761 / acc 85.71428680419922
# 1.0 : loss 0.3100111484527588 / acc 90.0
#
# data loader 1 acc: tensor(96.8750)
# 0.0 : loss 0.22599436342716217 / acc 94.7368392944336
# 1.0 : loss 0.13074322044849396 / acc 100.0
#
# data loader 2 acc: tensor(90.6250)
# 0.0 : loss 0.2316899448633194 / acc 92.0
# 1.0 : loss 0.19982048869132996 / acc 85.71428680419922
#
# ==================================================
# loaded model is binaryNN_3.pt
# cumulated total training/test acc: tensor(89.7959) / tensor(62.2328)
# 0.0 : loss 0.2703492343425751 / acc 89.92805480957031
# 1.0 : loss 0.3444831073284149 / acc 89.47368621826172
# test set performance
# 0.0 : loss 0.825018584728241 / acc 64.82084655761719
# 1.0 : loss 1.155545949935913 / acc 55.26315689086914
# --------------------------------------------------
# data loader 0 acc: tensor(86.)
# 0.0 : loss 0.33159339427948 / acc 87.14286041259766
# 1.0 : loss 0.5298241376876831 / acc 83.33332824707031
#
# data loader 1 acc: tensor(96.8750)
# 0.0 : loss 0.18667380511760712 / acc 94.7368392944336
# 1.0 : loss 0.08942858129739761 / acc 100.0
#
# data loader 2 acc: tensor(93.7500)
# 0.0 : loss 0.2730965316295624 / acc 92.0
# 1.0 : loss 0.09717382490634918 / acc 100.0
#
# data loader 3 acc: tensor(90.6250)
# 0.0 : loss 0.1598331481218338 / acc 92.0
# 1.0 : loss 0.2711850106716156 / acc 85.71428680419922
#
# ==================================================
# loaded model is binaryNN_4.pt
# cumulated total training/test acc: tensor(85.5263) / tensor(62.7078)
# 0.0 : loss 0.34518617391586304 / acc 85.9756088256836
# 1.0 : loss 0.30579033493995667 / acc 84.375
# test set performance
# 0.0 : loss 0.8405851125717163 / acc 62.54071807861328
# 1.0 : loss 0.9521678686141968 / acc 63.157894134521484
# --------------------------------------------------
# data loader 0 acc: tensor(81.)
# 0.0 : loss 0.4982699155807495 / acc 82.85713958740234
# 1.0 : loss 0.40041014552116394 / acc 76.66666412353516
#
# data loader 1 acc: tensor(93.7500)
# 0.0 : loss 0.22914166748523712 / acc 89.47368621826172
# 1.0 : loss 0.13050779700279236 / acc 100.0
#
# data loader 2 acc: tensor(81.2500)
# 0.0 : loss 0.3696497976779938 / acc 76.0
# 1.0 : loss 0.1872071921825409 / acc 100.0
#
# data loader 3 acc: tensor(84.3750)
# 0.0 : loss 0.1570889949798584 / acc 92.0
# 1.0 : loss 0.5157012939453125 / acc 57.14285659790039
#
# data loader 4 acc: tensor(96.8750)
# 0.0 : loss 0.1682034432888031 / acc 96.0
# 1.0 : loss 0.1339704990386963 / acc 100.0
#
# ==================================================
# loaded model is binaryNN_5.pt
# cumulated total training/test acc: tensor(84.6154) / tensor(65.0831)
# 0.0 : loss 0.3093923330307007 / acc 86.0215072631836
# 1.0 : loss 0.3932640254497528 / acc 81.0810775756836
# test set performance
# 0.0 : loss 0.8729939460754395 / acc 63.84364700317383
# 1.0 : loss 0.8098863959312439 / acc 68.42105102539062
# --------------------------------------------------
# data loader 0 acc: tensor(75.)
# 0.0 : loss 0.4110851287841797 / acc 78.57142639160156
# 1.0 : loss 0.6047616600990295 / acc 66.66666412353516
#
# data loader 1 acc: tensor(84.3750)
# 0.0 : loss 0.3176402151584625 / acc 89.47368621826172
# 1.0 : loss 0.4035003185272217 / acc 76.9230728149414
#
# data loader 2 acc: tensor(84.3750)
# 0.0 : loss 0.33502325415611267 / acc 80.0
# 1.0 : loss 0.24193483591079712 / acc 100.0
#
# data loader 3 acc: tensor(96.8750)
# 0.0 : loss 0.18353325128555298 / acc 96.0
# 1.0 : loss 0.14546139538288116 / acc 100.0
#
# data loader 4 acc: tensor(87.5000)
# 0.0 : loss 0.22003912925720215 / acc 88.0
# 1.0 : loss 0.20493942499160767 / acc 85.71428680419922
#
# data loader 5 acc: tensor(100.)
# 0.0 : loss 0.19415314495563507 / acc 100.0
# 1.0 : loss 0.15624678134918213 / acc 100.0
#
# ==================================================
# loaded model is binaryNN_6.pt
# cumulated total training/test acc: tensor(84.9315) / tensor(66.2708)
# 0.0 : loss 0.3173622190952301 / acc 86.9565200805664
# 1.0 : loss 0.46086570620536804 / acc 80.0
# test set performance
# 0.0 : loss 0.7379140853881836 / acc 69.05537414550781
# 1.0 : loss 0.9081851840019226 / acc 58.77193069458008
# --------------------------------------------------
# data loader 0 acc: tensor(78.)
# 0.0 : loss 0.4100673794746399 / acc 80.0
# 1.0 : loss 0.7152138352394104 / acc 73.33332824707031
#
# data loader 1 acc: tensor(90.6250)
# 0.0 : loss 0.22615182399749756 / acc 89.47368621826172
# 1.0 : loss 0.2074137181043625 / acc 92.30769348144531
#
# data loader 2 acc: tensor(78.1250)
# 0.0 : loss 0.3832070827484131 / acc 80.0
# 1.0 : loss 0.3279399871826172 / acc 71.42857360839844
#
# data loader 3 acc: tensor(90.6250)
# 0.0 : loss 0.15415839850902557 / acc 92.0
# 1.0 : loss 0.4009791314601898 / acc 85.71428680419922
#
# data loader 4 acc: tensor(96.8750)
# 0.0 : loss 0.22060179710388184 / acc 96.0
# 1.0 : loss 0.11782048642635345 / acc 100.0
#
# data loader 5 acc: tensor(78.1250)
# 0.0 : loss 0.3288383483886719 / acc 86.36363220214844
# 1.0 : loss 0.5608431696891785 / acc 60.0
#
# data loader 6 acc: tensor(96.8750)
# 0.0 : loss 0.30986925959587097 / acc 100.0
# 1.0 : loss 0.3174850046634674 / acc 90.90908813476562
#
# ==================================================
# loaded model is binaryNN_7.pt
# cumulated total training/test acc: tensor(90.4321) / tensor(65.0831)
# 0.0 : loss 0.31272321939468384 / acc 88.74459075927734
# 1.0 : loss 0.2423442155122757 / acc 94.6236572265625
# test set performance
# 0.0 : loss 0.8858760595321655 / acc 65.1465835571289
# 1.0 : loss 0.8798255920410156 / acc 64.91227722167969
# --------------------------------------------------
# data loader 0 acc: tensor(81.)
# 0.0 : loss 0.5480185151100159 / acc 78.57142639160156
# 1.0 : loss 0.27271029353141785 / acc 86.66666412353516
#
# data loader 1 acc: tensor(93.7500)
# 0.0 : loss 0.26535162329673767 / acc 89.47368621826172
# 1.0 : loss 0.15827248990535736 / acc 100.0
#
# data loader 2 acc: tensor(90.6250)
# 0.0 : loss 0.33488455414772034 / acc 88.0
# 1.0 : loss 0.17999723553657532 / acc 100.0
#
# data loader 3 acc: tensor(93.7500)
# 0.0 : loss 0.09691537916660309 / acc 96.0
# 1.0 : loss 0.3720942735671997 / acc 85.71428680419922
#
# data loader 4 acc: tensor(93.7500)
# 0.0 : loss 0.157863587141037 / acc 92.0
# 1.0 : loss 0.08240221440792084 / acc 100.0
#
# data loader 5 acc: tensor(96.8750)
# 0.0 : loss 0.18839797377586365 / acc 95.45454406738281
# 1.0 : loss 0.25954291224479675 / acc 100.0
#
# data loader 6 acc: tensor(93.7500)
# 0.0 : loss 0.30964916944503784 / acc 90.47618865966797
# 1.0 : loss 0.19133222103118896 / acc 100.0
#
# data loader 7 acc: tensor(100.)
# 0.0 : loss 0.14344635605812073 / acc 100.0
# 1.0 : loss 0.3943212032318115 / acc 100.0
#
# ==================================================
# loaded model is binaryNN_8.pt
# cumulated total training/test acc: tensor(82.3034) / tensor(65.7957)
# 0.0 : loss 0.40769267082214355 / acc 82.4000015258789
# 1.0 : loss 0.4197259545326233 / acc 82.07546997070312
# test set performance
# 0.0 : loss 0.6979125738143921 / acc 66.123779296875
# 1.0 : loss 0.7167661190032959 / acc 64.91227722167969
# --------------------------------------------------
# data loader 0 acc: tensor(76.)
# 0.0 : loss 0.5373941659927368 / acc 75.71428680419922
# 1.0 : loss 0.48509877920150757 / acc 76.66666412353516
#
# data loader 1 acc: tensor(84.3750)
# 0.0 : loss 0.5100381970405579 / acc 84.21052551269531
# 1.0 : loss 0.4136286675930023 / acc 84.61537170410156
#
# data loader 2 acc: tensor(81.2500)
# 0.0 : loss 0.47698065638542175 / acc 76.0
# 1.0 : loss 0.30624955892562866 / acc 100.0
#
# data loader 3 acc: tensor(87.5000)
# 0.0 : loss 0.23496106266975403 / acc 88.0
# 1.0 : loss 0.4347027540206909 / acc 85.71428680419922
#
# data loader 4 acc: tensor(96.8750)
# 0.0 : loss 0.1931668072938919 / acc 96.0
# 1.0 : loss 0.1377314031124115 / acc 100.0
#
# data loader 5 acc: tensor(78.1250)
# 0.0 : loss 0.397420197725296 / acc 81.81818389892578
# 1.0 : loss 0.42562636733055115 / acc 70.0
#
# data loader 6 acc: tensor(81.2500)
# 0.0 : loss 0.4644395709037781 / acc 76.19047546386719
# 1.0 : loss 0.25267869234085083 / acc 90.90908813476562
#
# data loader 7 acc: tensor(90.6250)
# 0.0 : loss 0.2902131676673889 / acc 95.83333587646484
# 1.0 : loss 0.49391835927963257 / acc 75.0
#
# data loader 8 acc: tensor(78.1250)
# 0.0 : loss 0.3432786762714386 / acc 78.9473648071289
# 1.0 : loss 0.5713652968406677 / acc 76.9230728149414
#
# ==================================================
# loaded model is binaryNN_9.pt
# cumulated total training/test acc: tensor(87.3711) / tensor(67.2209)
# 0.0 : loss 0.3403812050819397 / acc 85.71428680419922
# 1.0 : loss 0.24715641140937805 / acc 91.3043441772461
# test set performance
# 0.0 : loss 0.8926104307174683 / acc 65.1465835571289
# 1.0 : loss 0.7138475775718689 / acc 72.80701446533203
# --------------------------------------------------
# data loader 0 acc: tensor(82.)
# 0.0 : loss 0.5018104314804077 / acc 78.57142639160156
# 1.0 : loss 0.2933097779750824 / acc 90.0
#
# data loader 1 acc: tensor(78.1250)
# 0.0 : loss 0.370846152305603 / acc 73.68421173095703
# 1.0 : loss 0.30985796451568604 / acc 84.61537170410156
#
# data loader 2 acc: tensor(87.5000)
# 0.0 : loss 0.4502476751804352 / acc 84.0
# 1.0 : loss 0.1629810333251953 / acc 100.0
#
# data loader 3 acc: tensor(96.8750)
# 0.0 : loss 0.14417190849781036 / acc 96.0
# 1.0 : loss 0.1595679074525833 / acc 100.0
#
# data loader 4 acc: tensor(93.7500)
# 0.0 : loss 0.17294661700725555 / acc 92.0
# 1.0 : loss 0.07766614109277725 / acc 100.0
#
# data loader 5 acc: tensor(93.7500)
# 0.0 : loss 0.21376216411590576 / acc 95.45454406738281
# 1.0 : loss 0.22247837483882904 / acc 90.0
#
# data loader 6 acc: tensor(78.1250)
# 0.0 : loss 0.5212836861610413 / acc 66.66666412353516
# 1.0 : loss 0.2063755989074707 / acc 100.0
#
# data loader 7 acc: tensor(84.3750)
# 0.0 : loss 0.3291800618171692 / acc 87.5
# 1.0 : loss 0.4016333520412445 / acc 75.0
#
# data loader 8 acc: tensor(93.7500)
# 0.0 : loss 0.18537941575050354 / acc 94.7368392944336
# 1.0 : loss 0.20332534611225128 / acc 92.30769348144531
#
# data loader 9 acc: tensor(96.8750)
# 0.0 : loss 0.19573618471622467 / acc 100.0
# 1.0 : loss 0.2712637484073639 / acc 88.88888549804688

# %%
from utils.data_utils import dataset_description, dl2nparray

# %%
for i in range(len(dl_loaders)):
    print("data loader",i)
    x,y,z = dl2nparray(dl_loaders[i])
    dataset_description(x,y,z)
# Out:
# data loader 0
# data loader 1
# data loader 2
# data loader 3
# data loader 4
# data loader 5
# data loader 6
# data loader 7
# data loader 8
# data loader 9
# data loader 10

# %%
for i in range(len(dl_loaders)):
    print("data cumulative loader",i)
    x,y,z = dl2nparray(dl_cum_loaders[i])
    dataset_description(x,y,z)
# Out:
# data cumulative loader 0
# data cumulative loader 1
# data cumulative loader 2
# data cumulative loader 3
# data cumulative loader 4
# data cumulative loader 5
# data cumulative loader 6
# data cumulative loader 7
# data cumulative loader 8
# data cumulative loader 9
# data cumulative loader 10

# %%
x,y,z = dl2nparray(test_loader)
dataset_description(x,y,z)
