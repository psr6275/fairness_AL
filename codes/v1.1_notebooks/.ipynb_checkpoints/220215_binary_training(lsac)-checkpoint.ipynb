# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
device = torch.device('cuda:0')

# %%
from utils.data_utils import dataset_description, input_uniqueness, initial_dataloaders
from utils.data_utils import load_data_with_name

# %%
from utils import config

# %%
args_dic = {}
args_dic['epochs'] = 1
args_dic['batch_size']=64
args_dic['AL_iters'] = 10
args_dic['AL_batch']=32
args_dic['AL_select']='acc'
args_dic['init_num'] = 100
args_dic['val_ratio'] =0.2 
args_dic['problem_type'] = 'binary' 
args_dic['model_type'] ='NN'
args_dic['model_args'] ={'n_hidden':32, 'p_dropout':0.0}
args_dic['dataset'] = 'lsac'
args_dic['save_model']=True
args_dic['save_dir'] = None

# %%
args = config.Args(**args_dic)
# args = config.Args(epochs = 100, batch_size=64, 
#                    AL_iters = 10, AL_batch=32, AL_select='acc',
#                    init_num = 100, val_ratio =0.2, 
#                    problem_type = 'binary', 
#                    model_type='NN', model_args={'n_hidden':32, 'p_dropout':0.0},
#                    dataset = 'lsac', save_model=True, save_dir = None)
# Out:
# need to set selection params!
# save directory:  ../results/lsac/220219_1503

# %%
Xtr, Xte, ytr, yte, Ztr, Zte = load_data_with_name(args.dataset, 
                                                   svm=False, random_state=42,intercept=False)

# %%
dataset_description(Xtr,ytr,Ztr, dataname=args.dataset+'_train')
dataset_description(Xte,yte,Zte, dataname=args.dataset+'_test')

# %%
input_uniqueness(Xtr,Xte)
# Out:
# 26551 26480
# redundant examples:  71

# %%
args.print_args()
# Out:
# train epochs/batch: 100/64
# AL iters/batch: 10/32
# AL selection is based on  acc
# initial number and validation ratio are 100/0.2
# problem and models are binary/NN

# %%
sel_args = {"param_names":None, "last_layer":True, "sel_idxs": None, "normalize":True}
sel_type = "entropy"
args.set_selection_params(sel_type,sel_args)

# %%
N1 = args.init_num
train_loader, select_loader, test_loader = initial_dataloaders(Xtr,ytr,Ztr,Xte,yte,Zte,N1,args)

# %% [markdown]
# # Train model

# %%
from utils.train_utils import train_AL, train_AL_valid

# %%
clf, train_loader_p, select_loader_p = train_AL(train_loader, select_loader, device, 
                                                      args, test_loader, True)
# Out:
# Accuracy
# 	training         	 (min:   77.000, max:   77.000, cur:   77.000)
# 	validation       	 (min:   80.003, max:   80.015, cur:   80.003)
# Loss
# 	training         	 (min:    0.471, max:    0.682, cur:    0.471)
# 	validation       	 (min:    0.483, max:    0.677, cur:    0.484)
# Finished Training
# 0.0 : loss 0.424694687128067 / acc 81.13207244873047
# 1.0 : loss 0.5211985111236572 / acc 72.34042358398438
# /home/srp/research/Fairness/fairness_AL/codes/utils/data_utils.py:141: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   tensors = (torch.tensor(da).clone().detach().float() for da in dataarrays)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-14-dbfdad4f0697> in <module>
# ----> 1 clf, train_loader_p, select_loader_p = train_AL(train_loader, select_loader, device,
#       2                                                       args, test_loader, True)
#
# ~/research/Fairness/fairness_AL/codes/utils/train_utils.py in train_AL(train_loader, select_loader, device, args, test_loader, from_scratch)
#      56                                       args.AL_select, args.problem_type, return_loader = True)
#      57
# ---> 58         sidx = select_examples(clf,worst_loader,select_loader,device,args.AL_batch,
#      59                                              args.sel_fn, **args.sel_args)
#      60
#
# ~/research/Fairness/fairness_AL/codes/utils/binary_utils.py in select_examples_binary(clf, val_loader, sel_loader, device, sel_batch_num, criterion_type, **sel_args)
#     122                                             criterion_type, **sel_args)
#     123     elif criterion_type == 'entropy':
# --> 124         sel_idxs = compute_indv_entropy(clf, sel_loader, device,sel_batch_num)
#     125     else:
#     126         sel_idxs = torch.tensor(list(np.range(sel_loader.dataset.tensor[0].shape[0])))
#
# ~/research/Fairness/fairness_AL/codes/utils/binary_utils.py in compute_indv_entropy(clf, dataloader, device, sel_batch_num)
#      86         loss = criterion(outs)
#      87         losses.append(loss.detach().cpu())
# ---> 88     max_outs = torch.topk(torch.cat(losses),sel_batch_num)
#      89     return max_outs[1]
#      90
#
# RuntimeError: selected index k out of range

# %%
from utils.data_utils import save_dataloader

# %%
save_dataloader(args.save_dir,test_loader)
# Out:
# test_loader.pkl is stored in ../results/lsac/220215_1248/test_loader.pkl

# %%
import os
f = open(os.path.join(args.save_dir,'train_AL.txt'),'w')    
f.close()

# %%
with open(os.path.join(args.save_dir,'train_AL.txt'),'w') as f:
    f.write(str(args_dic))
    f.write("\n")
    f.write(sel_type)
    f.write("\n")
    f.write(str(sel_args))
