# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

device = torch.device('cuda:2')

# %%
import numpy as np

# %%
from utils.data_utils import load_simulation_data

# %%
Xtr,Xte,ytr,yte,Ztr,Zte = load_simulation_data(simulation_params = {'p':100,'q':40, 'r':20, 'b':-10, 't':0}, 
                                               n1=1000, n2=400, svm=False, random_state=55, intercept=False, 
                                               train_frac = 0.7)

# %%
from utils.data_utils import dataset_description, input_uniqueness, initial_dataloaders
from utils.data_utils import load_data_with_name

# %%
dataset_description(Xtr,ytr,Ztr, dataname='_train')
dataset_description(Xte,yte,Zte, dataname='_test')

# %%
input_uniqueness(Xtr,Xte)
# Out:
# 1400 1400
# satisfy uniqueness

# %%
from utils.data_utils import NPsDataSet
from torch.utils.data import DataLoader

batch_size = 64

train_data = NPsDataSet(Xtr, ytr, Ztr)
train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True, drop_last=False)

test_data = NPsDataSet(Xte, yte, Zte)
test_loader = DataLoader(test_data, batch_size=batch_size, shuffle=False, drop_last=False)

# %% [markdown]
# # Train model

# %%
from utils.train_utils import train_AL, train_AL_valid,train_AL_valid_trgrad

# %%
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from utils.binary_utils import construct_model_binary

model_arg={'n_hidden':32,'p_dropout':0.2}

clf = construct_model_binary('NN',Xte.shape[1],**model_arg)
criterion = nn.BCELoss()
optimizer = optim.Adam()
# Out:
# Accuracy
# 	training         	 (min:   39.643, max:   97.500, cur:   87.171)
# 	validation       	 (min:   33.333, max:   75.000, cur:   57.143)
# Loss
# 	training         	 (min:    0.170, max:    0.721, cur:    0.283)
# 	validation       	 (min:    0.658, max:    1.284, cur:    0.875)
# test_acc
# 	test_acc         	 (min:   45.606, max:   70.071, cur:   65.796)
# test_loss
# 	test_loss        	 (min:    0.600, max:    0.984, cur:    0.807)
# Finished Training
# 0.0 : loss 0.3824034631252289 / acc 83.33333587646484
# 1.0 : loss 0.43560805916786194 / acc 79.66101837158203
# final dataloader is saved in  ../results/simulation/220310_1731/final_dataloader.pkl

# %%
from utils.data_utils import save_dataloader

# %%
save_dataloader(args.save_dir,test_loader)
# Out:
# test_loader.pkl is stored in ../results/simulation/220310_1731/test_loader.pkl

# %%
import os

# %%
with open(os.path.join(args.save_dir,'train_AL.txt'),'w') as f:
    f.write(str(args_dic))
    f.write("\n")
    f.write(sel_type)
    f.write("\n")
    f.write(str(sel_args))

# %%
import pickle
with open(os.path.join(args.save_dir,'selected_group_results.pkl'),'wb') as f:
    pickle.dump(gids, f)
